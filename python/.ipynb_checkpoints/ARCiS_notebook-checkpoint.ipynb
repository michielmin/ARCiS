# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
import pyARCiS

# %%
# initialize ARCiS from input file input.dat, store output in <output>
# the third argument with commandline options is optional
pyARCiS.pyinit('input.dat','output','-s emisspec=.true. -s computeT=.true.')
# Out:
# Output dir: output/
# ==================================================================
#          ARtful modelling code for exoplanet Science - ARCiS
# ==================================================================
# By using ARCiS you agree to the terms of use.
# It basically means you offer us co-author rights on any paper
# that uses results computed with ARCiS.
# ==================================================================
# Let's get the show on the road!!
# ARCiS version x.`DOmP���F"P�� h �EOmP���@COmx�����E"`COmx�`��*���COmD�P����COm̯ B"                P����EOm���`�DOm�K
# ==================================================================
# input file: input.dat
# Command line argument: emisspec=.true.
# Command line argument: computeT=.true.
# Number of molecules:          4
# Number of clouds:             0
# Number of collision pairs:    2
# Number of observations:       0
# Planet logg:    3.414
# ==================================================================
# Reading in correlated k-tables for H2O
#    wavelength range: 1.00E-01 - 5.00E+01 micron
#      pressure range: 1.00E-05 - 1.00E+02 bar
#   temperature range: 1.00E+02 - 3.40E+03 K
# reading UV opacities for lambda < 2.36E-01 micron
# Reading in correlated k-tables for CO2
#    wavelength range: 3.00E-01 - 5.00E+01 micron
#      pressure range: 1.00E-05 - 1.00E+02 bar
#   temperature range: 1.00E+02 - 3.40E+03 K
# Reading in correlated k-tables for H2
#    wavelength range: 5.00E-01 - 3.50E+01 micron
#      pressure range: 1.00E-07 - 1.00E+03 bar
#   temperature range: 7.10E+01 - 2.90E+03 K
# reading UV opacities for lambda < 5.07E-01 micron
# Opacity file not available: /Users/michielm/ARCiS/Data/Opacities/opacity_He.fits.gz
# setting opacities to 0
# Reading CIA opacities
# Reading file:/Users/michielm/ARCiS/Data/CIA/H2-H2_combined.cia
# CIA: H2-H2
# Reading file:/Users/michielm/ARCiS/Data/CIA/H2-He_2011.cia
# CIA: H2-He
#
#  elemental abundances and masses ...
#  ===================================
#  reading kp-data from /Users/michielm/ARCiS/Data/GGchem/dispol_BarklemCollet.dat ...
#  reading kp-data from /Users/michielm/ARCiS/Data/GGchem/dispol_StockKitzmann_withoutTsuji.dat ...
#  reading kp-data from /Users/michielm/ARCiS/Data/GGchem/dispol_WoitkeRefit.dat ...
#  reading kp-data from /Users/michielm/ARCiS/Data/GGchem/dispol_Burcat_ARCiS.dat ...
#
#          505  species
#           21  elements
#    H  He   C   N   O  Na  Mg  Si  Fe  Al  Ca  Ti   S  Cl   K  Li   P   V   F  Cr  el
#    1   2   6   7   8  11  12  14  26  13  20  22  16  17  19   3  15  23   9  24   0
#   12   2   5   3  10   2   2   3   2   2   2   1   8   6   2   3   4   1  10   1   1
#    H+ HE+  C+  N+  O+ NA+ MG+ SI+ FE+ AL+ CA+ TI+  S+ CL+  K+ LI+  P+  V+  F+ CR+
# ==================================================================
# ==================================================================

# %%
lam=np.empty([pyARCiS.pyex.nlam],dtype=float)
trans=np.empty([pyARCiS.pyex.nlam],dtype=float)
emis=np.empty([pyARCiS.pyex.nlam],dtype=float)
P=np.empty([pyARCiS.pyex.nr],dtype=float)
T=np.empty([pyARCiS.pyex.nr],dtype=float)
pyARCiS.pycomputemodel()
pyARCiS.pygettrans(lam,trans)
pyARCiS.pyverbose(False)

# %%
for i in range(0,41):
    Z=float(i)/10.0-2.0
# pysetvalue sets a keyword using a string and a float (key and value)
    pyARCiS.pysetvalue('metallicity',Z)
    print(Z)
# pycomputemodel computes a model using the current setup
    pyARCiS.pycomputemodel()
    pyARCiS.pygettrans(lam,trans)
#    plt.xscale('log')
#    plt.plot(lam, trans, color=(i/40,0,0),zorder=200)
# Out:
# -2.0
# -1.9
# -1.8
# -1.7
# -1.6
# -1.5
# -1.4
# -1.3
# -1.2
# -1.1
# -1.0
# -0.8999999999999999
# -0.8
# -0.7
# -0.6000000000000001
# -0.5
# -0.3999999999999999
# -0.30000000000000004
# -0.19999999999999996
# -0.10000000000000009
# 0.0
# 0.10000000000000009
# 0.20000000000000018
# 0.2999999999999998
# 0.3999999999999999
# 0.5
# 0.6000000000000001
# 0.7000000000000002
# 0.7999999999999998
# 0.8999999999999999
# 1.0
# 1.1
# 1.2000000000000002
# 1.2999999999999998
# 1.4
# 1.5
# 1.6
# 1.7000000000000002
# 1.7999999999999998
# 1.9
# 2.0

# %%
# pysetkeyword sets a keyword using two strings (key and value)
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# note that you always have to be carefull changing things after initialization. 
# For physical parameters (abundances, radius, mass, chemical parameters ...) it is always fine
# For retrieval parameters it is always fine
# For parameters defining the setup (number of layers, chemistry on/off, spectral resultion ...) 
#                                        it is usually NOT fine
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

pyARCiS.pysetkeyword('scattering','.true.')
pyARCiS.pysetkeyword('scattstar','.true.')

for i in range(0,4):
    Z=float(i)
    pyARCiS.pysetvalue('metallicity',Z)
    pyARCiS.pycomputemodel()
    pyARCiS.pygetemis(lam,emis,1)    
    plt.xscale('log')
    plt.plot(lam, emis, color=(i/4,0,0),zorder=200)

# %%
for i in range(0,4):
    Z=float(i)
    pyARCiS.pysetvalue('metallicity',Z)
    pyARCiS.pycomputemodel()
    pyARCiS.pygetpt(P,T)
    plt.plot(T,P, color=(i/4,0,0),zorder=200)
    plt.ylim(1000,1e-8)
    plt.yscale('log')
